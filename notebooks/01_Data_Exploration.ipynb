# %% [markdown]
# # 01 - Data Exploration
# Initial look at the raw `job_applicant_dataset.csv` before any cleaning.

# %%
import sys
sys.path.append('..')
from src.data_loader import DataLoader
from src.utils import Paths

loader = DataLoader(Paths.RAW_DATA)
df = loader.load()
df.head()

# %%
loader.print_profile()

# %% [markdown]
# **Observation:** the raw dataset contains candidate demographics, free-text resumes, job roles/descriptions, and a `Best Match` label — it does not contain a recruitment funnel, salary, or recruiter data. See `README.md` for how this is handled.
