# %% [markdown]
# # 02 - Data Cleaning
# Applies the `DataCleaner` pipeline: dedupe, missing values, dtype conversion, standardization, validation.

# %%
import sys
sys.path.append('..')
from src.data_loader import DataLoader
from src.preprocessing import DataCleaner
from src.utils import Paths

raw_df = DataLoader(Paths.RAW_DATA).load()
cleaned_df = DataCleaner(raw_df).run_all()
cleaned_df.head()

# %%
print('Rows before:', len(raw_df))
print('Rows after :', len(cleaned_df))
cleaned_df.isnull().sum()
